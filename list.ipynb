# %%
# python -m ipykernel install --user --name pykernel --display-name "Python Kernel"

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

print(fruits)
# Out:
# ['사과', '바나나', '딸기']

# %%
# 리스트
fruits = []

print(fruits)
# Out:
# []

# %%
# 리스트
number = 10

print(number)
print(type(number))
# Out:
# 10
# <class 'int'>

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

print(type(fruits))
# Out:
# <class 'list'>

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

fruits.append("포도")

print(fruits)
# Out:
# ['사과', '바나나', '딸기', '포도']

# %%
# 리스트
fruits = ["사과", "바나나", "딸기", "포도"]

fruits.remove("바나나")

print(fruits)
# Out:
# ['사과', '딸기', '포도']

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

fruits.remove("포도")

print(fruits)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 fruits = ["사과", "바나나", "딸기"]
#       2
# ----> 3 fruits.remove("포도")
#       4
#       5 print(fruits)
#
# ValueError: list.remove(x): x not in list

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

for fruit in fruits:
    print(fruit)
# Out:
# 사과
# 바나나
# 딸기

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

for _ in fruits:
    print("과일이 하나 있습니다.")
# Out:
# 과일이 하나 있습니다.
# 과일이 하나 있습니다.
# 과일이 하나 있습니다.

# %%
# 리스트
for number in range(5):
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# 리스트
for number in range(1, 5):
    print(number)
# Out:
# 1
# 2
# 3
# 4

# %%
# 리스트
for number in range(3, 8):
    print(number)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
# 리스트
for number in range(1, 10, 2):
    print(number)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# 리스트
for number in range(10, 0, -2):
    print(number)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

print(fruits[0])
# Out:
# 사과

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

print(fruits[0])
print(fruits[1])
print(fruits[2])
# Out:
# 사과
# 바나나
# 딸기

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

print(fruits[-1])
# Out:
# 딸기

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

print(fruits[-1])
print(fruits[-2])
print(fruits[-3])
# Out:
# 딸기
# 바나나
# 사과

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

print(len(fruits))
# Out:
# 3

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

print("사과" in fruits)
# Out:
# True

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

print("포도" in fruits)
# Out:
# False

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

for index, fruit in enumerate(fruits):
    print(index, fruit)
# Out:
# 0 사과
# 1 바나나
# 2 딸기

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

for index, fruit in enumerate(fruits, 1):
    print(index, fruit)
# Out:
# 1 사과
# 2 바나나
# 3 딸기

# %%
# 리스트
fruits = ["사과", "바나나", "딸기"]

result = [fruit for fruit in fruits]

print(result)
# Out:
# ['사과', '바나나', '딸기']

# %%
# 리스트
numbers = [1, 2, 3, 4, 5]

result = [number * 2 for number in numbers]

print(result)
# Out:
# [2, 4, 6, 8, 10]

# %%
# 리스트
numbers = [number for number in range(1, 6)]

print(numbers)

# %%
# 리스트
numbers = [number for number in range(1, 6)]

print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 리스트
numbers = [1, 2, 3, 4, 5, 6]

result = [number for number in numbers if number > 3]

print(result)
# Out:
# [4, 5, 6]

# %%
# 리스트
numbers = [1, 2, 3, 4, 5, 6]

result = [number * 2 for number in numbers if number % 2 == 0]

print(result)
# Out:
# [4, 8, 12]

# %%
# 리스트
fruits1 = ["사과", "바나나"]
fruits2 = ["딸기", "포도"]

fruits = fruits1 + fruits2

print(fruits)
# Out:
# ['사과', '바나나', '딸기', '포도']

# %%
# 리스트
fruits = ["사과", "바나나"]

fruits.append("딸기")
print(fruits)
# Out:
# ['사과', '바나나', '딸기']

# %%
# 리스트
fruits = ["사과", "바나나"]

fruits.extend(["포도", "수박"])
print(fruits)
# Out:
# ['사과', '바나나', '포도', '수박']

# %%
# 리스트
fruits = ["사과", "바나나"]

fruits.insert(1, "오렌지")
print(fruits)
# Out:
# ['사과', '오렌지', '바나나']
